# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('data/Xeek_Well_15-9-15.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     WELL  DEPTH_MD         GROUP FORMATION  CALI      RDEP  \
# 0       18270  15/9-15   485.256  NORDLAND GP.       NaN   NaN  1.735962
# 1       18271  15/9-15   485.408  NORDLAND GP.       NaN   NaN  1.744778
# 2       18272  15/9-15   485.560  NORDLAND GP.       NaN   NaN  1.752990
# 3       18273  15/9-15   485.712  NORDLAND GP.       NaN   NaN  1.760675
# 4       18274  15/9-15   485.864  NORDLAND GP.       NaN   NaN  1.767360
#
#    RHOB         GR  NPHI  PEF         DTC   LITH
# 0   NaN  78.275825   NaN  NaN  161.947510  Shale
# 1   NaN  79.214615   NaN  NaN  161.267715  Shale
# 2   NaN  79.724106   NaN  NaN  160.644363  Shale
# 3   NaN  81.042778   NaN  NaN  160.212601  Shale
# 4   NaN  80.785133   NaN  NaN  160.315948  Shale

# %%
g = sns.FacetGrid(df)
g.map(sns.scatterplot, 'NPHI', 'RHOB', alpha=0.5);

# %%
g = sns.FacetGrid(df, col='LITH', col_wrap=4)
g.map(sns.scatterplot, 'NPHI', 'RHOB', alpha=0.5)
g.set(xlim=(-0.15, 1))
g.set(ylim=(3, 1))
